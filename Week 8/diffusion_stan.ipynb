# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import stan
import arviz as az

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Introduction
#
# In this notebook, we will estimate the parameters of the simple diffusion model from a simulated response times (RTs) data set using Stan's implementation of Hamiltonian Monte Carlo (HMC). But, wait! Since we are simulating the data (i.e., solving the forward problem), don't we already know the parameters with absolute certainty? Indeed, in this case we do, and this little exercise will introduce a crucial principle of all computational modeling: **Parametric models are nothing but assumptions about the unknown data-generating process**, so, in a way, the inverse problem (i.e., going from data to parameters) presupposes the forward problem.
#
# Thus, even when we are estimating the parameters from an actually observed data set, we are assuming that the parametric model is the accurate description of the system that generated the data. In other words, we hope that our model is *well-specified*. Simulation studies enable science *in silico*, that is, before collecting any data, we can already play oracles and test what we can learn from the data by successively solving the forward and the inverse problem.

# %% [markdown]
# ## Diffusion Model Simulator

# %%
def simulate_diffusion(v, a, beta, tau, dt=1e-3, scale=1.0, max_time=10., rng=None):
    """
    Simulates one realization of the diffusion process given
    a set of parameters and a step size `dt`.

    Parameters:
    -----------
    v        : float
        The drift rate (rate of information uptake)
    a        : float
        The boundary separation (decision threshold).
    beta     : float in [0, 1]
        Relative starting point (prior option preferences)
    tau      : float
        Non-decision time (additive constant)
    dt       : float, optional (default: 1e-3 = 0.001)
        The step size for the Euler algorithm.
    scale    : float, optional (default: 1.0)
        The scale (sqrt(var)) of the Wiener process. Not considered
        a parameter and typically fixed to either 1.0 or 0.1.
    max_time : float, optional (default: .10)
        The maximum number of seconds before forced termination.
    rng      : np.random.Generator or None, optional (default: None)
        A random number generator with locally set seed or None
        If None provided, a new generator will be spawned within the function.
        
    Returns:
    --------
    (x, c) - a tuple of response time (y - float) and a 
        binary decision (c - int) 
    """

    # Inits (process starts at relative starting point)
    y = beta * a
    num_steps = tau
    const = scale*np.sqrt(dt)
    if rng is None:
        rng = np.random.default_rng()

    # Loop through process and check boundary conditions
    while (y <= a and y >= 0) and num_steps <= max_time:

        # Perform diffusion equation
        z = rng.normal()
        y += v*dt + const*z

        # Increment step counter
        num_steps += dt

    if y >= a:
        c = 1.
    else:
        c = 0.
    return (round(num_steps, 4), c)

# %% [markdown]
# ## Helper Functions

# %%
def simulate_diffusion_n(num_sims, v, a, beta, tau, dt=1e-3, scale=1.0, max_time=10., rng=None):
    """Add a nice docstring."""

    # Inits
    data = np.zeros((num_sims, 2))
    if rng is None:
        rng = np.random.default_rng()
    
    # Create data set
    for n in range(num_sims):
        data[n, :] = simulate_diffusion(v, a, beta, tau, dt, scale, max_time, rng)
    return data


def visualize_data(data, figsize=(10, 5)):
    """Helper function to visualize a simple response time data set."""

    f, axarr = plt.subplots(1, 2, figsize=figsize)
    
    # Histogram of response times
    sns.histplot(
        data[:, 0][data[:, 1] == 1], ax=axarr[0], color='#AA0000', alpha=0.8, lw=2, label=f'Response 1')
    sns.histplot(
        data[:, 0][data[:, 1] == 0], ax=axarr[0], color='#0000AA', alpha=0.8, lw=2, label=f'Response 0')

    # Barplot of categorical responses
    response, frequency = np.unique(data[:, 1], return_counts=True)
    sns.barplot(x=response.astype(np.int32), y=frequency, ax=axarr[1], alpha=0.8, color='#00AA00')

    # Labels and embelishments
    axarr[0].set_xlabel('Response time (s)', fontsize=16)
    axarr[0].legend(fontsize=16)
    axarr[0].set_ylabel('Count', fontsize=16)
    axarr[1].set_xlabel('Response', fontsize=16)
    axarr[1].set_ylabel('Frequency', fontsize=16)
    for ax in axarr:
        sns.despine(ax=ax)
        ax.grid(alpha=0.1, color='black')

    f.suptitle('Data Summary', fontsize=18)

    f.tight_layout()

# %%
# Ensure reproducibility
RNG = np.random.default_rng(2024)

# Set ground-truth parameters
parameters = {
    'v': 1.6,
    'a': 0.8,
    'beta': 0.6,
    'tau': 0.4
}

# Set additional simulation settings
control = {
    'num_sims': 120,
    'rng': RNG,
    'dt': 1e-3
}

# Create data with above configuration
data = simulate_diffusion_n(**{**control, **parameters})

# %%
visualize_data(data)

# %% [markdown]
# ## Bayesian Parameter Estimation
#
# Now, we will write a Stan program to sample from the posterior of the diffusion model parameters given the observed data.

# %% [markdown]
# ### Stan Program

# %%
program_code = """

data {
    int<lower=1> N;
    array[N] real<lower=0> y;
    array[N] int<lower=0, upper=1> c;
}

parameters {
    real<lower=0> v;
    real<lower=0> a;
    real<lower=0, upper=1> beta;
    real<lower=0> tau;
}

model {
    // Priors
    v ~ gamma(3, 1);
    a ~ gamma(3, 1);
    beta ~ beta(2, 2);
    tau ~ gamma(2, 1);

    // Likelihood
    for (n in 1:N) {
        // Your code here
    }
}
"""

# %% [markdown]
# ### Visualizing the Prior Distributions

# %%
### Visualizing our priors the lazy way

f, axarr = plt.subplots(1, 4, figsize=(12, 3))
param_names = [r'Drift rate ($v$)', r'Boundary separation ($a$)', r'Bias ($\beta$)', r'Non-decision time ($\tau$)']
sns.histplot(np.random.gamma(3, 1, size=100000), color='maroon', ax=axarr[0])
sns.histplot(np.random.gamma(3, 1, size=100000), color='maroon', ax=axarr[1])
sns.histplot(np.random.beta(2, 2, size=100000), color='maroon', ax=axarr[2])
sns.histplot(np.random.gamma(2, 1, size=100000), color='maroon', ax=axarr[3])

for ax, p in zip(axarr, param_names):
    ax.set_title(p, fontsize=14)
    ax.set_xlabel('Parameter value', fontsize=12)
    ax.set_yticks([])
    ax.set_ylabel('')
    sns.despine(ax=ax)

f.tight_layout()

# %% [markdown]
# ### Compilation and Sampling

# %%
# Prepare data in Stan friendly format
data_dict = {
    'y': data[:, 0], 
    'c': data[:, 1].astype(int),
    'N': data.shape[0]
}

# Compile model
model = stan.build(program_code, data=data_dict)
# Out:
# Building...
# Building: 14.2s, done.

# %%
# Posterior inference using MCMC
fit = model.sample(num_chains=4, num_warmup=1000, num_samples=2500)
# Out:
# Sampling:   0%
# Sampling:   0% (1/14000)
# Sampling:   0% (2/14000)
# Sampling:   0% (3/14000)
# Sampling:   0% (4/14000)
# Sampling:   1% (103/14000)
# Sampling:   1% (202/14000)
# Sampling:   2% (301/14000)
# Sampling:   4% (500/14000)
# Sampling:   5% (700/14000)
# Sampling:   7% (1000/14000)
# Sampling:   9% (1300/14000)
# Sampling:  11% (1500/14000)
# Sampling:  14% (1900/14000)
# Sampling:  16% (2200/14000)
# Sampling:  18% (2500/14000)
# Sampling:  20% (2800/14000)
# Sampling:  40% (5600/14000)
# Sampling:  60% (8400/14000)
# Sampling:  80% (11200/14000)
# Sampling: 100% (14000/14000)
# Sampling: 100% (14000/14000), done.
# Messages received during sampling:
#   Gradient evaluation took 0.000829 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 8.29 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.39874e+194 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 18.495 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.593833 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418437 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414956 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414242 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.415935 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.41551 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.432421 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.444323 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412249 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412302 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.762919 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.000749 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 7.49 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.79839e+25 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 6.94671e+25 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.71894e+06 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 8.59034 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 21, column 4 to column 22)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.24513e+10 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.416694 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.452, but must be greater than nondecision time = 0.452331 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.423506 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.43085 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.43198 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.470243 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.438103 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413815 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.419061 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.41574 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.417266 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.475998 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.463275 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.420615 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.459858 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.421659 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.64976 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.00053 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 5.3 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 9.87706e+76 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 7.74314e+18 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 13534.6 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.61004 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.430536 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.58942e+07 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418124 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412647 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.421074 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.417893 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.463531 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418694 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414003 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.447826 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.422976 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412684 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.473082 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 4.2485 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.000489 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 4.89 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414801 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.425481 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.416364 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.41414 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.41853 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.959995 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.416624 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.41423 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.427991 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.438019 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.04557 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.431583 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.416818 (in '/tmp/httpstan_lx2t1vev/model_rr4mn6cs.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
# Extract samples
df = fit.to_frame()

# %%
# Posterior summary statistics
az.summary(fit)
# Out:
#        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# v     2.049  0.316   1.437    2.634      0.005    0.003    4686.0    4602.0
# a     0.903  0.051   0.810    0.999      0.001    0.000    5388.0    5716.0
# beta  0.552  0.040   0.480    0.627      0.001    0.000    4465.0    5824.0
# tau   0.391  0.006   0.380    0.401      0.000    0.000    4485.0    4877.0
#
#       r_hat
# v       1.0
# a       1.0
# beta    1.0
# tau     1.0

# %%
# Traceplots 
f = az.plot_trace(fit, compact=False, legend=True)
plt.tight_layout()
# Out:
# /home/radevs/anaconda3/envs/cognitive/lib/python3.11/site-packages/arviz/plots/backends/matplotlib/traceplot.py:433: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for chain_id in range(data.dims["chain"])

# %%
# Inspect diagnostics and create custom functions
